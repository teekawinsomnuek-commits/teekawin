# %% [markdown]
# <a href="https://colab.research.google.com/github/teekawinsomnuek-commits/teekawin/blob/main/disnyalla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1hoF1yzQTHHabs-uLhjeLfLkB6xjNL86W" width="500px">

# %% [markdown]
# # **ชื่อกลุ่ม**:ชอพอพาเก็บA
# # ชื่อสมาชิก:
# 1. นางสาวกัลยรัตน์ อุปมัย รหัสนักศึกษา 683020237-1
# 2. นายธีร์กวิน สุทธวงค์ รหัสนักศึกษา 683020248-6
# 3. นางสาวพิมพ์วลัญช์ นิลดวง รหัสนักศึกษา 683020256-7
# 4. นายศุทธวีร์ ยืนสุข รหัสนักศึกษา 683020058-1
# 5. นายพีรพัฒน์ ฤทธิ์สยาม รหัสนักศึกษา 683020257-5
# 6. นายเอกราช บุญแสง รหัสนักศึกษา 683020265-6

# %% [markdown]
# ข้อมูลที่สนใจ:ข้อมูลจำนวนผู้ใช้งาน Disny+
# ในแต่ละเดือน โดยข้อมูลประกอบด้วย จำนวนผู้ใช้ในแต่ละเดือนและการเปลี่ยนแปลงของจำนวนผู้ใช้

# %% [markdown]
# ประโยชน์ของข้อมูล:สามารถนำข้อมูลไปวิเคราะห์แนวโน้มจำนวนผู้ใช้งาน เปรียบเทียบการเพิ่มขึ้นหรือลดลงของผู้ใช้ในแต่ละเดือนและช่วยในการวางแผนการตลาดหรือพัฒนาการบริการให้ตรงกับความต้องการของผู้ใช้งาน
